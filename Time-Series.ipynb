# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('D:\Diet_gym_financeDATASet.csv', skiprows=1 )
df.head()
# Out:
#       Mois  diet: (Dans tous les pays)  gym: (Dans tous les pays)  \
# 0  2004-01                         100                         28
# 1  2004-02                          75                         23
# 2  2004-03                          67                         25
# 3  2004-04                          68                         21
# 4  2004-05                          71                         21
#
#    finance: (Dans tous les pays)
# 0                             48
# 1                             48
# 2                             46
# 3                             45
# 4                             43

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Mois                           227 non-null    object
#  1   diet: (Dans tous les pays)     227 non-null    int64
#  2   gym: (Dans tous les pays)      227 non-null    int64
#  3   finance: (Dans tous les pays)  227 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # Rename Columns

# %%
df.columns=['month', 'diet','gym','finance']
df.head()
# Out:
#      month  diet  gym  finance
# 0  2004-01   100   28       48
# 1  2004-02    75   23       48
# 2  2004-03    67   25       46
# 3  2004-04    68   21       45
# 4  2004-05    71   21       43

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    227 non-null    object
#  1   diet     227 non-null    int64
#  2   gym      227 non-null    int64
#  3   finance  227 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.2+ KB

# %%
df['month']=pd.to_datetime(df['month'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    227 non-null    datetime64[ns]
#  1   diet     227 non-null    int64
#  2   gym      227 non-null    int64
#  3   finance  227 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 7.2 KB

# %% [markdown]
# # make Month Column as Index

# %%
df.set_index('month',inplace=True)
df.head()
# Out:
#             diet  gym  finance
# month
# 2004-01-01   100   28       48
# 2004-02-01    75   23       48
# 2004-03-01    67   25       46
# 2004-04-01    68   21       45
# 2004-05-01    71   21       43

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 227 entries, 2004-01-01 to 2022-11-01
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   diet     227 non-null    int64
#  1   gym      227 non-null    int64
#  2   finance  227 non-null    int64
# dtypes: int64(3)
# memory usage: 7.1 KB

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df['diet'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df['diet'].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.rolling(12).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='month'>
